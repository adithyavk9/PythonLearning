# %% [markdown]
# <h2 align="left">Functions</h2>

# %%
############## Function #################
"""
1. In Python, a function is a group of statements that performs some task. It returns some value at
end.
2. Procedure are similar to functions but it should not returen a value. It only performs the
tasks. But the control will be returned to the calling function.
3. In both, we can have parameters.
4. A paremeter is the variables listed inside the parenthesis in the function definition.
5. An argument is the value that is sent to the function when it is called.
6. Function increses the code reusability and reduce the LOC.
"""

# # General Structure
# def functionName(argument1, argument2, argumentN):
#     statement(s)
#     # print('I am done')
#     return return1, return2, returnN
# You can also return nothing.

# x, y, z = functionName(10,20,30)

# sumOfTwoNumbers

# %%
def sum_of_two_numbers():#we are creating a new function. def is used to create functin definition
    a = 3
    b = 5
    c = a+b
    print ("the sum is ", c)

def sum_of_two_numbers1(a, b):  # parameters are catching the valures based on the positions
    print ("the sum is ", a+b) # inside the function, we are printing the values

def sum_of_two_numbers2(a, b): # we are throwing the result
    return a*b

# %%
sum_of_two_numbers() # we are calling the function
sum_of_two_numbers()
# Out:
# the sum is  8
# the sum is  8

# %%
sum_of_two_numbers1(2,3) # while calling the function, we pass arguments
sum_of_two_numbers1(3,4) # throwing the value
sum_of_two_numbers1(4,5)
# Out:
# the sum is  5
# the sum is  7
# the sum is  9

# %%
sum_of_two_numbers2(10,2)
# Out:
# 20

# %%
print("the mul is ",sum_of_two_numbers2(12,13))
result = sum_of_two_numbers2(13,14) # results = 27
print ("the mul is ", result)
#sum_of_two_numbers2(14,15)
# Out:
# the mul is  156
# the mul is  182

# %%
def even(n):
    if n % 2 == 0:
        is_even = True
    else:
        is_even = False
    return is_even

n1 = 4
print(even(n1))
n2 = 7
print(even(n2))
# Out:
# True
# False

# %%
def even(n):
    return n % 2 == 0

n1 = 20
print(even(n1))
n2 = 13
print(even(n2))
# Out:
# True
# False

# %%
def mad_calculator(n1, n2):
    return n1+n2, n1-n2, n1*n2, n1/n2, n1%n2, n1//n2, n1**n2

a1 = 10
a2 = 5
print(mad_calculator(a1, a2))

a3 = 20
a4 = 4
ret1, ret2, ret3, ret4, ret5, ret6, ret7 = mad_calculator(a3, a4)
print(ret1, ret2, ret3, ret4, ret5, ret6, ret7)
# Out:
# (15, 5, 50, 2.0, 0, 2, 100000)
# 24 16 80 5.0 0 5 160000

# %%
def add_sub (x, y):
    c = x + y
    d = x - y
    return c, d
r1, r2 = add_sub(5, 4)
print(r1, r2)
print(add_sub(5,5))
# Out:
# 9 1
# (10, 0)

# %%
def update(x):
    print(id(x))
    x = 8
    print(id(x))
    print("x ", x)
    # return x

# %%
a = 10
print(id(a))
# Out:
# 138561864401424

# %%
update(a)
# Out:
# 138561864401424
# 138561864401360
# x  8

# %%
print("a", a)
print(id(a))
# Out:
# a 8
# 138614748742096

# %%
update(a)
print("a", a)

# %%
def update(lst):
    print(id(lst))
    lst[1] = 'Bikash' #25
    print(id(lst))
    print("lst ", lst)

lst1 = [10, 20, 30]
print(id(lst1))
update(lst1)
print("lst1 ", lst1)
# Out:
# 138614334076864
# 138614334076864
# 138614334076864
# lst  [10, 'Bikash', 30]
# lst1  [10, 'Bikash', 30]

# %%
# Default Values

def power(x, p=1):
    return x**p

print(power(x=10))
print(power(10, 3))

print(power(p=10, x=3))
# Out:
# 10
# 1000
# 59049

# %%
def my_details (name, age, loc = "Delhi"): #user-defined function. You can also create default value
    print("My name is: ", name)
    print("My age is: ",age)
    print("My location is: ", loc)

my_details (age = 38, name = "Bikash", loc = "Kolkata")  # here the arguments are keyword-based
# Out:
# My name is:  Bikash
# My age is:  38
# My location is:  Kolkata

# %%
my_details (age = 38, name = "Bikash")
# Out:
# My name is:  Bikash
# My age is:  38
# My location is:  Delhi

# %%
####### Another Example (passing list parameter) ##########

def check_even (full_list): # function definition
    even_found = [] # empty list
    for nums in full_list: # every elemnts will checked
        if nums % 2 == 0:  # checking whether it is divisible by 2
            even_found.append(nums) # if divisible add it to the empty list
        else:
            pass # do nothing
    return even_found

limit = int (input("Please enter the upper limit for natural numbers: ")) #typecasting
# input function is used to take user input and it return string object.

natural_number = list(range(1,limit+1)) # typecasting range object----> list object
print(natural_number)
print(check_even(natural_number))
print(check_even([20,30,100,3,5,8]))
# Out:
# Please enter the upper limit for natural numbers: 700
# ...

# %%
# Default values MUST be filled from the right
def power(x=1, p):
    return x**p

print(power(10, 3))
# Out:
#   File "<ipython-input-47-fc05662a8312>", line 2
#     def power(x=1, p):
#                    ^
# SyntaxError: non-default argument follows default argument

# %%
########### Lambda Function ############
"""
1. Python Lambda functions are anonymous functions which means that the functions are without name
2. Lambda keyword is used to create such function.
Syntax:
lambda arguments: expression
5. Multiple arguments can be there.
6. Single line.
"""
a = 10
l_func = lambda a: a+10
l_func1 = lambda b: b*9
print (type(l_func))
print(type(a))
print (l_func(100))
print (l_func1(20))
# Out:
# <class 'function'>
# <class 'int'>
# 110
# 180

# %%
aa1 = lambda a,b: (a+b, a*b, a/b, a**b)
print("the answer is:", aa1(10,30))
# Out:
# the answer is: (40, 300, 0.3333333333333333, 1000000000000000000000000000000)

# %%
## Example

def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y != 0:
        return x / y
    else:
        return "Error: Cannot divide by zero."

# Get input from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
operation = input("Choose operation (+, -, *, /): ")

# Perform the selected operation
if operation == '+':
    result = add(num1, num2)
elif operation == '-':
    result = subtract(num1, num2)
elif operation == '*':
    result = multiply(num1, num2)
elif operation == '/':
    result = divide(num1, num2)
else:
    result = "Invalid operation."

# Print the result
print(f"The result of {num1} {operation} {num2} is: {result}")
# Out:
# Enter the first number: 10
# Enter the second number: 20
# Choose operation (+, -, *, /): +
# The result of 10.0 + 20.0 is: 30.0

# %% [markdown]
# Exercise: Write a function for calculating area of a rectangle. Please take two sides of the rectangle from user and call the function.

# %%
def calculate_rectangle_area(length, width):
    area = length * width
    return area

# Get input from the user
length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))

# Call the function to calculate the area
area = calculate_rectangle_area(length, width)

# Print the result
print(f"The area of the rectangle with length {length} and width {width} is: {area}")

### Alternate approach
area = lambda length, width: length*width
# Print the result
print(f"The area of the rectangle with length {length} and width {width} is: {area(length, width)}")

# %% [markdown]
# Exercise: Write a function for calculating factorial of a number taken from user as input.

# %%
## Non-recursive
def factorial(n):
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result

### Recursive
def factorial(n):
    if n==0:
      return 1
    return n * factorial(n-1)

# Get input from the user
number = int(input("Enter a number to calculate its factorial: "))

# Call the factorial function and print the result
result = factorial(number)
print(f"The factorial of {number} is: {result}")
# Out:
# Enter a number to calculate its factorial: 5
# The factorial of 5 is: 120

# %% [markdown]
# Exercise: Write a function for checking prime number. Input a number from user and call the function to test it.

# %%
def is_prime(number):
    if number <= 1:
        return False
    for i in range(2, int(number**0.5) + 1): # 2 to the square root of the number and checks
                                             #if any of these values divides the number evenly
        if number % i == 0:
            return False
    return True

# Get input from the user
num = int(input("Enter a number to check if it's prime: "))

# Call the function to check if the number is prime
prime_check = is_prime(num)

# Print the result
if prime_check:
    print(f"{num} is a prime number.")
else:
    print(f"{num} is not a prime number.")
# Out:
# Enter a number to check if it's prime: 2
# 2 is a prime number.

# %%
x = 2
for i in range(2,int(x) + 1):
  print(i)
# Out:
# 2

# %%
## Exercise: Recursive method for calculating nCr

# %%
## Exercise: Recursive method for generating Fibonacci sequence

# %%
######## variable number of arguments (dynamically) #########

def my_mul_add(*args): # function defination of a user defined function
    print(type(args))
    i = 0
    mul = 1
    while (i<len(args)): ####### i=0, len(args)---->4
        mul = mul * args[i] ### i=0--> mul = 1 * 10,i=1--> mul = 10 * 12,i=2--> mul = 120 * 3
                            ### i=3--> mul = 360 * 4
        i+=1
    print ("The mul result is: ", mul)
    return sum(args) # I have used a library func (sum)

print("The sum is: ",my_mul_add(10,12,3,4)) # I have called the function
# Out:
# <class 'tuple'>
# The mul result is:  1440
# The sum is:  29

# %%
def my_key_value(**kvp):
    print(type(kvp))
    print("The collection is: ", kvp)
    for a in kvp:
        print(kvp[a], end=" ")

my_key_value(name = "Palash", age=35, loc = "Kolkata")
## you can pass any number of key-value pairs.
# Out:
# <class 'dict'>
# The collection is:  {'name': 'Palash', 'age': 35, 'loc': 'Kolkata'}
# Palash 35 Kolkata

# %%
####################### Nested Functions ##########################
def i_am_outsider():
    print ("I am the outsider function")
    def i_am_insider(a): # insider function
        print("I am the inner function", a)

    i_am_insider(5) # call is ok. Why? Because we are calling from inside the function
    i_am_insider(10)

    # return

# %%
x = i_am_outsider()
print(x)
# Out:
# I am the outsider function
# I am the inner function 5
# I am the inner function 10
# None

# %%
i_am_insider() # out of scope can not be called
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-f3db87f4f7f5> in <cell line: 1>()
# ----> 1 i_am_insider() # out of scope can not be called
#
# NameError: name 'i_am_insider' is not defined

# %% [markdown]
# Returning function from function

# %%
## If you want to access the inner function, then
## return the inner function from the outer function

def i_am_outsider():
    print ("I am the outsider function")
    def i_am_insider(a): # insider function
        print("I am the inner function", a)

    def i_am_insider_2(a): # insider function
        print("I am the inner function", a)

    i_am_insider(5) # call is ok. Why? Because we are calling from inside the function
    i_am_insider(10)

    return (i_am_insider, i_am_insider_2)

# %%
## storing the output. As output is function, now treat x as a function.
x, y = i_am_outsider()
# Out:
# I am the outsider function
# I am the inner function 5
# I am the inner function 10

# %%
## Calling inner function, which is now x
x(100)
y(200)
# Out:
# I am the inner function 100
# I am the inner function 200

# %% [markdown]
# Passing the function as an argument

# %%
# Python program to illustrate functions
# can be passed as arguments to other functions
def shout(text):
    return text.upper()

def whisper(text):
    return text.lower()

def func(text):
    return text

def greet(func):
    # storing the function in a variable

    ## Calling func
    greeting = func("""Hi, I am created by a function passed as an argument.""")

    print(greeting)

# %%
shout("""Hi, I am created by a function passed as an argument.""")
# Out:
# 'HI, I AM CREATED BY A FUNCTION PASSED AS AN ARGUMENT.'

# %%
greet(func)
# Out:
# Hi, I am created by a function passed as an argument.

# %%
greet(whisper)

# %% [markdown]
# Function decorators

# %%
"""
Function decorators
-------------------

A decorator is a function that takes another function as its argument, and returns another function.
For example, let's create a function such that we can print a message before and after a function is called.
This could be used to keep track of function calls and for debugging.

"""

def decorator(f):
    def wrapper():
        print('First line')
        f()
        print('Third line')
    return wrapper

def func():
    print('Second line')

# %%
f2 = decorator(func)

# %%
f2()
# Out:
# First line
# Second line
# Third line

# %% [markdown]
# As you can see, f() printed, as desired, the corresponding messages before/after the function is executed.
#
# The decor() function is a decorator and f = decor(f) can be achieved by adding @decor right above the definition of the function f():

# %%
@decorator
def func():
    print('Second line')

# %%
func()
# Out:
# First line
# Second line
# Third line

# %% [markdown]
# As you can see, it prints exactly the same as before.
#
# Let's now decorate a function that takes arguments and returns something.
# In this case, the wrapper() function needs to have arguments and pass them to the func() function and return the result of the function.
#
# Let's take a look at this example in which I print some information which could,once again, be helpful for debugging purposes. In this cases, the decorator prints the name of the function together with the provided arguments,
# and what the function returned.

# %%
from functools import wraps

def debug(f):
    @wraps(f)  # this will preserve information about the original function (for example, to get correct f.__name__)
    def wrapper(*args):
        print(f'DEBUG: Calling {f.__name__} with arguments={args}')
        result = f(*args)
        print(f'DEBUG: {f.__name__} returned {result}')
        return result
    return wrapper

@debug
def sum_args(*args12):
    return sum(list(args12))

result111 = sum_args(100, 200, 300)
print(result111)
# Out:
# DEBUG: Calling sum_args with arguments=(100, 200, 300)
# DEBUG: sum_args returned 600
# 600

# %% [markdown]
# Let's now use multiple decorators, where one of them have arguments. The first decorator will be the debug decorator already defined above. The second one, will be a new one which is used to call a function multiple times, as many as requested.

# %%
def repeat(n = 2):
    def repeat_decorator(f):
        # @wraps(f)
        def repeater(*args):
            result = [f(*args) for i in range(n)]
            return result
        return repeater
    return repeat_decorator

@debug
@repeat(n = 3)
def print_hello():
    print('Hello')
    return 'success'

print_hello()
# Out:
# DEBUG: Calling print_hello with arguments=()
# Hello
# Hello
# Hello
# DEBUG: print_hello returned ['success', 'success', 'success']
# ['success', 'success', 'success']

# %%
######################################
## Filter function

nums = [2,3,4,5,6,7,8]
evens = list (filter(lambda n: n%2==0, nums)) # filter-->library function

print(evens)
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# Scope of variables

# %%
a = 1   ## Global variable
def my_func():
    a = 2  ## Local variable
    print(f'a inside my_func() = {a}')

my_func()
print(f'a outside my_func() = {a}')
# Out:
# a inside my_func() = 1
# a outside my_func() = 1

# %% [markdown]
# Function annotations

# %%
def create_dict(x: int, y: str) -> dict:   ## Annotation for the return type (not checked by the compiler). It is called type hints
    """Example of a function using annotations"""  ## Description
    return {x: y} # note: I'm using dictionary comprehension here

# %% [markdown]
# Function with multiple return value

# %%
def return_multiple_objects(x, y) -> tuple:
    return x+2, y+3

# %%
my_tuple = return_multiple_objects(1,2)
print(f'{my_tuple = }')  # get the tuple
print(f'{my_tuple[0] = }')  # get first value of the tuple
print(f'{my_tuple[1] = }')  # get second value of the tuple

# %% [markdown]
# <h2 align="left">Examples of helpful built-in functions</h2>

# %% [markdown]
# File I/O

# %%
from google.colab import drive
drive.mount('/gdrive7')
# Out:
# Mounted at /gdrive7

# %%
cd '/gdrive7/My Drive/Colab Notebooks/Python Prog for Data Eng'
# Out:
# /gdrive7/My Drive/Colab Notebooks/Python Prog for Data Eng

# %%
f1 = open('afile.txt', 'w')

f1.write('zzzz... huh?\n')
f1.write('*cough cough*')

f1.close()

# %%
f1 = open('afile.txt', 'r')

c1 = f1.readline()
print(c1)

f1.close()
# Out:
# zzzz... huh?

# %%
f1 = open('afile.txt', 'r')

c1 = f1.read()
print(c1)

f1.close()
# Out:
# zzzz... huh?
# *cough cough*

# %%
f1 = open('afile.txt', 'r')

for c1 in f1:
    print(c1)

f1.close()
# Out:
# zzzz... huh?
#
# *cough cough*

# %% [markdown]
# String

# %%
s1 = 'abcd'
s2 = 'defg'

print(s1)
print(s2)
print(s1+s2)

print(s1.upper())
print(len(s1))

s3 = '       this is a sentence       '
print(s3)
print(s3.strip())

l1 = (s3.strip()).split() # other arguments for split
print(l1)
s4 = ' '.join(l1)
print(s4)
# Out:
# abcd
# defg
# abcddefg
# ABCD
# 4
#        this is a sentence
# this is a sentence
# ['this', 'is', 'a', 'sentence']
# this is a sentence

# %% [markdown]
# ### List of strings functions
#
#
# 1. capitalize(): Converts the first character to upper case \
# 2. casefold(): Converts string into lower case \
# 3. center(): Returns a centered string \
# 4. count(): Returns the number of times a specified value occurs in a string \
# 5. encode(): Returns an encoded version of the string \
# 6. endswith(): Returns true if the string ends with the specified value \
# 7. expandtabs(): Sets the tab size of the string \
# 8. find(): Searches the string for a specified value and returns the position of where it was found \
# 9. format(): Formats specified values in a string \
# 10. format_map(): Formats specified values in a string \
# 11. index(): Searches the string for a specified value and returns the position of where it was found \
# 12. isalnum(): Returns True if all characters in the string are alphanumeric \
# 13. isalpha(): Returns True if all characters in the string are in the alphabet \
# 14. isdecimal(): Returns True if all characters in the string are decimals \
# 15. isdigit(): Returns True if all characters in the string are digits \
# 16. isidentifier(): Returns True if the string is an identifier \
# 17. islower(): Returns True if all characters in the string are lower case \
# 18. isnumeric(): Returns True if all characters in the string are numeric \
# 19. isprintable(): Returns True if all characters in the string are printable \
# 20. isspace(): Returns True if all characters in the string are whitespaces \
# 21. istitle(): Returns True if the string follows the rules of a title \
# 22. isupper(): Returns True if all characters in the string are upper case \
# 23. join(): Joins the elements of an iterable to the end of the string \
# 24. ljust(): Returns a left justified version of the string \
# 25. lower(): Converts a string into lower case \
# 26. lstrip(): Returns a left trim version of the string \
# 27. maketrans(): Returns a translation table to be used in translations \
# 28. partition(): Returns a tuple where the string is parted into three parts \
# 29. replace(): Returns a string where a specified value is replaced with a specified value \
# 30. rfind(): Searches the string for a specified value and returns the last position of where it was found \
# 31. rindex(): Searches the string for a specified value and returns the last position of where it was found \
# 32. rjust(): Returns a right justified version of the string \
# 33. rpartition(): Returns a tuple where the string is parted into three parts \
# 34. rsplit(): Splits the string at the specified separator, and returns a list \
# 35. rstrip(): Returns a right trim version of the string \
# 36. split(): Splits the string at the specified separator, and returns a list \
# 37. splitlines(): Splits the string at line breaks and returns a list \
# 38. startswith(): Returns true if the string starts with the specified value \
# 39. strip(): Returns a trimmed version of the string \
# 40. swapcase(): Swaps cases, lower case becomes upper case and vice versa \
# 41. title(): Converts the first character of each word to upper case \
# 42. translate(): Returns a translated string \
# 43. upper(): Converts a string into upper case \
# 44. zfill(): Fills the string with a specified number of 0 values at the beginning
# 45. chr(): Converts an integer to a character
# 46. ord(): Converts a character to an integer
# 47. len(): Returns the length of a string
# 48. str(): Returns a string representation of an object

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
dir(len)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__text_signature__']
